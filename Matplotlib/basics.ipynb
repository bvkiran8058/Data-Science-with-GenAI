# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
apple_stocks = pd.read_csv('../data/AAPL.csv', usecols=['date', 'open', 'close'], index_col='date', parse_dates=['date'])
apple_stocks.head()
# Out:
#                              close    open
# date
# 2015-05-27 00:00:00+00:00  132.045  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.20
# 2015-06-02 00:00:00+00:00  129.960  129.86

# %%
apple_stocks.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ## line plots

# %%
apple_stocks = pd.read_csv('../data/AAPL.csv', usecols=['date', 'open', 'close', 'high', 'low'], index_col='date', parse_dates=['date'])
apple_stocks.head()
# Out:
#                              close     high     low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.05  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.10  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.90  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.05  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.32  129.86

# %%
apple_stocks.loc['2016-05'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
apple_stocks.loc['2016-05'].plot(y=['low', 'high'])
# Out:
# <Axes: xlabel='date'>

# %%
apple_stocks.loc['2016'].plot(subplots=True, figsize=(15,8))
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>], dtype=object)
